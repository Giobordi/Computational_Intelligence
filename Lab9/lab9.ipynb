# %% [markdown]
# # LAB9
#
# Write a local-search algorithm (eg. an EA) able to solve the *Problem* instances 1, 2, 5, and 10 on a 1000-loci genomes, using a minimum number of fitness calls. That's all.

# %%
from random import choices, random, randint
from math import ceil
from copy import deepcopy
import lab9_lib

# %% [markdown]
# ### Genetic Algorithm
#
# Initial settings:
# - POP_SIZE = 100
# - OFFSPRING_SIZE = 20 🧬
# - GENERATIONS = 1000
# - TOURNAMENT_SIZE = 30
# - MUTATION_PROBABILITY = 0.5 🎰
#
# There are also 3 other parameters:
# - ADAPTABILITY : is an int that represents the number of generations that the algorithm will run, before the update of some parameters
# - TOURNAMENT_MODIFIER = 2, is the value for the self-adaptation of the tournament size
# - MUTATION_MODIFIER = 0.03, is the value for the self-adaptation of the mutation probability
#
#
# I decided to use a 'plus' strategy, so the offspring will be added to the population.
# The selection is made with a tournament selection approach and the size of the tournament is self-adapted based on the performance of the algorithm.
# The mutation probability is also self-adapted based on the performance of the algorithm.
#
# The main idea of my algorithm is to evaluate the fitness on subchunks of the genome, saving the fitness value of each subchunk (avoiding to recompute it if it is already computed due the fact the fitness function is costly), saving the chuck structure in SUB_CHUNKS_SAVED and the fitness value in SUB_FITNESS_SAVED.
#
# The idea is to maximize the fitness of each subchunk, the length of the subchunk 2*instance.
#
# The crossover is made by taking the best subchunk between the two parents, this is done for each subchunk of the genome.

# %%
SUB_CHUNKS_SAVED = [] ##for optimization reasons 
SUB_FITNESS_SAVED = [] ##for optimization reasons
class Individual:
    def __init__(self, genome,fit, k):
        self.genome = genome
        self.fitness = fit
        if k < 10 :
            k = k * 2
        self.sub_chunks = [self.genome[i:i+k] for i in range(0, len(self.genome), k)]
        self.fitness_chunk = [self.chunk_fitness_alredy_computed(i) for i in range(len(self.sub_chunks))]
    
    def chunk_fitness_alredy_computed(self, chunk_index : int) -> float:
        '''
        Search in the rest of the chunks if the fitness is already computed
        '''
        tmp_chunk = self.sub_chunks[chunk_index]
        if tmp_chunk in SUB_CHUNKS_SAVED:
            return SUB_FITNESS_SAVED[SUB_CHUNKS_SAVED.index(tmp_chunk)]
        else:
            SUB_CHUNKS_SAVED.append(tmp_chunk)
            fit = fitness(tmp_chunk)
            SUB_FITNESS_SAVED.append(fit)
            return fit

# %%
instances = [1,2,5,10,20]
POP_SIZE = 100
OFFSPRING_SIZE =  20
LOCI = 10000
MUTATION_RATE = 0.8
GENERATIONS = 1000
TOURNAMENT_SIZE = 30 
INCREASING_THRESHOLD = 0.01
MUTATION_MODIFIER = 0.03
TOURNAMENT_MODIFIER = 2
ADAMPTABILITY = 10
MUTATION_DIVIDER = 100
K = instances[4]
fitness = lab9_lib.make_problem(K)

# %%
def create_population(pop_size : int, loci : int) -> list:
    population = []
    for _ in range(pop_size):
        genome = choices([0, 1], k=loci)
        fit = fitness(genome)
        population.append(Individual(genome,fit, K))
    return population

# %% [markdown]
# ### Functions to manage self-adaptation

# %%
def adaptive_tournament_size(adaptation : list[float], tournament_size : int) -> int : 
    flat_land = set(adaptation)
    if len(flat_land) == 1:
        tournament_size-=TOURNAMENT_MODIFIER*3    
    elif adaptation[-1] < adaptation[0] + INCREASING_THRESHOLD:
        ## favours exploration
        tournament_size -= TOURNAMENT_MODIFIER
    
    elif adaptation[-1] >= adaptation[0] + INCREASING_THRESHOLD:
        ## favours exploitation
        tournament_size += TOURNAMENT_MODIFIER
    if tournament_size > 500:
        tournament_size = 500
    elif tournament_size < 2: ##with comma the min should be 10
        tournament_size = 2
    return tournament_size

def adaptive_mutation_rate(adaptation : list[float], mutation_rate : float) -> float : 

    flat_land = set(adaptation)
    if len(flat_land) == 1:
        mutation_rate*=1.3    
        print("Flat land")
    elif adaptation[-1] < adaptation[0] + INCREASING_THRESHOLD:
        ## favours exploration
        mutation_rate += MUTATION_MODIFIER
    
    elif adaptation[-1] >= adaptation[0] + INCREASING_THRESHOLD:
        ## favours exploitation
        mutation_rate -= MUTATION_MODIFIER
    if mutation_rate > 1.0:
        mutation_rate = 1.0
    elif mutation_rate < 0.0:
        mutation_rate = 0.0
    return mutation_rate

# %% [markdown]
# ### Genetic Algorithm

# %%
def genetic_algorithm(population : list[Individual], offspring_size : int, tournament_size : int, mutation_rate : float, generations : int) -> Individual:
    list_of_best = []
    current_best = max(population, key=lambda ind: ind.fitness).fitness
    list_of_best.append(current_best) 
    for _ in range(generations):
        offspring = []
        for i in range(offspring_size):
            parent1 = tournament_selection(population, tournament_size)
            parent2 = tournament_selection(population, tournament_size)
            offspring.append(uniform_sub_chuncks_crossover(parent1, parent2))
            
        for index, ind in enumerate(offspring):
            if random() < mutation_rate:
                offspring[index] = mutate_sub_chuncks(ind, mutation_rate)
        pop_size = len(population)
        population += offspring
        population = sorted(population, key = lambda x : x.fitness , reverse=True)[:pop_size]

        if population[0].fitness > current_best + 0.05:
            print(f"Good improvement, fitness increased of {(population[0].fitness - current_best):.2%} ↗️")
        current_best = population[0].fitness
        list_of_best.append(current_best)
        if _ % ADAMPTABILITY == 0 and _ != 0:
            mutation_rate = adaptive_mutation_rate(list_of_best, mutation_rate)
            tournament_size = adaptive_tournament_size(list_of_best, tournament_size)
            list_of_best = [current_best]
        print(f"gen {_} Best fitness: {population[0].fitness:.2%} with mutation rate {mutation_rate:.2%} and tournament size {tournament_size} offspring size {offspring_size}")
        if current_best == 1.0:
            return population[0]
    return max(population, key=lambda ind: ind.fitness)


def tournament_selection(population : list[Individual], tournament_size : int) -> list:
    tournament = choices(population, k=tournament_size)
    return max(tournament, key=lambda ind: ind.fitness)

def uniform_sub_chuncks_crossover(parent1 : Individual, parent2 : Individual) -> Individual:
    genome = []
    for i in range(len(parent1.sub_chunks)):
        if parent1.fitness_chunk[i] >= parent2.fitness_chunk[i]:
            genome += parent1.sub_chunks[i]
        else:
            genome += parent2.sub_chunks[i]
    return Individual(genome=genome,fit=fitness(genome),k=K)

def mutate_sub_chuncks(ind : Individual, mutation_rate : float):
    ind = deepcopy(ind)
    for i in range(len(ind.sub_chunks)):
        if ind.fitness_chunk[i] < 1.0:
            indice = randint(0, len(ind.sub_chunks[i]) - 1) 
            ind.sub_chunks[i][indice] = 1-ind.sub_chunks[i][indice]  ###flip one bit tryin to improve the fitness   
            ind.fitness_chunk[i] = ind.chunk_fitness_alredy_computed(i)
    ind.fitness = sum(ind.fitness_chunk) / len(ind.fitness_chunk)
    return ind

# %%
top = genetic_algorithm(create_population(POP_SIZE, LOCI), OFFSPRING_SIZE, TOURNAMENT_SIZE, MUTATION_RATE, GENERATIONS)
print(f"Number of calls: {fitness.calls}")
# Out:
# Good improvement, fitness increased of 50.88% ↗️
# gen 0 Best fitness: 55.95% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 1 Best fitness: 60.30% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 2 Best fitness: 63.19% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 3 Best fitness: 65.25% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 4 Best fitness: 66.68% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 5 Best fitness: 68.16% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 6 Best fitness: 69.29% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 7 Best fitness: 70.96% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 8 Best fitness: 71.92% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 9 Best fitness: 72.78% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 10 Best fitness: 73.54% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 11 Best fitness: 73.73% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 12 Best fitness: 74.38% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 13 Best fitness: 74.87% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 14 Best fitness: 75.30% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 15 Best fitness: 75.91% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 16 Best fitness: 76.03% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 17 Best fitness: 76.29% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 18 Best fitness: 76.37% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 19 Best fitness: 76.56% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 20 Best fitness: 76.84% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 21 Best fitness: 77.50% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 22 Best fitness: 77.50% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 23 Best fitness: 77.60% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 24 Best fitness: 77.60% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 25 Best fitness: 77.89% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 26 Best fitness: 78.40% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 27 Best fitness: 78.46% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 28 Best fitness: 78.59% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 29 Best fitness: 78.90% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 30 Best fitness: 79.02% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 31 Best fitness: 79.02% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 32 Best fitness: 79.02% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 33 Best fitness: 79.02% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 34 Best fitness: 79.47% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 35 Best fitness: 79.65% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 36 Best fitness: 79.65% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 37 Best fitness: 79.65% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 38 Best fitness: 79.65% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 39 Best fitness: 79.65% with mutation rate 71.00% and tournament size 36 offspring size 20
# gen 40 Best fitness: 79.65% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 41 Best fitness: 79.65% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 42 Best fitness: 79.65% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 43 Best fitness: 79.65% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 44 Best fitness: 79.68% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 45 Best fitness: 79.68% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 46 Best fitness: 80.02% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 47 Best fitness: 80.02% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 48 Best fitness: 80.02% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 49 Best fitness: 80.16% with mutation rate 74.00% and tournament size 34 offspring size 20
# gen 50 Best fitness: 80.16% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 51 Best fitness: 80.46% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 52 Best fitness: 80.46% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 53 Best fitness: 80.51% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 54 Best fitness: 80.75% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 55 Best fitness: 80.75% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 56 Best fitness: 80.75% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 57 Best fitness: 80.75% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 58 Best fitness: 80.75% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 59 Best fitness: 81.01% with mutation rate 77.00% and tournament size 32 offspring size 20
# gen 60 Best fitness: 81.14% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 61 Best fitness: 81.14% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 62 Best fitness: 81.47% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 63 Best fitness: 81.60% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 64 Best fitness: 81.60% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 65 Best fitness: 81.60% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 66 Best fitness: 81.60% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 67 Best fitness: 81.60% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 68 Best fitness: 81.60% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 69 Best fitness: 81.60% with mutation rate 80.00% and tournament size 30 offspring size 20
# gen 70 Best fitness: 81.60% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 71 Best fitness: 81.60% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 72 Best fitness: 81.60% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 73 Best fitness: 81.60% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 74 Best fitness: 81.60% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 75 Best fitness: 81.62% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 76 Best fitness: 81.67% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 77 Best fitness: 81.75% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 78 Best fitness: 81.75% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 79 Best fitness: 81.98% with mutation rate 83.00% and tournament size 28 offspring size 20
# gen 80 Best fitness: 81.98% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 81 Best fitness: 82.09% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 82 Best fitness: 82.09% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 83 Best fitness: 82.09% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 84 Best fitness: 82.09% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 85 Best fitness: 82.09% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 86 Best fitness: 82.40% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 87 Best fitness: 82.40% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 88 Best fitness: 82.40% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 89 Best fitness: 82.40% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 90 Best fitness: 82.41% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 91 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 92 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 93 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 94 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 95 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 96 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 97 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 98 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 99 Best fitness: 83.08% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 100 Best fitness: 83.46% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 101 Best fitness: 83.54% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 102 Best fitness: 83.54% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 103 Best fitness: 83.56% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 104 Best fitness: 83.56% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 105 Best fitness: 83.56% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 106 Best fitness: 83.56% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 107 Best fitness: 83.58% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 108 Best fitness: 83.82% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 109 Best fitness: 83.82% with mutation rate 86.00% and tournament size 26 offspring size 20
# gen 110 Best fitness: 83.82% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 111 Best fitness: 83.82% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 112 Best fitness: 83.82% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 113 Best fitness: 83.85% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 114 Best fitness: 83.91% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 115 Best fitness: 83.91% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 116 Best fitness: 84.03% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 117 Best fitness: 84.09% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 118 Best fitness: 84.32% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 119 Best fitness: 84.32% with mutation rate 89.00% and tournament size 24 offspring size 20
# gen 120 Best fitness: 84.32% with mutation rate 92.00% and tournament size 22 offspring size 20
# gen 121 Best fitness: 84.32% with mutation rate 92.00% and tournament size 22 offspring size 20
# gen 122 Best fitness: 84.32% with mutation rate 92.00% and tournament size 22 offspring size 20
# gen 123 Best fitness: 84.34% with mutation rate 92.00% and tournament size 22 offspring size 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\giobo\Documents\Magistrale_2anno\Computational_Intelligence\Computational_Intelligence\Lab9\lab9.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> top = genetic_algorithm(create_population(POP_SIZE, LOCI), OFFSPRING_SIZE, TOURNAMENT_SIZE, MUTATION_RATE, GENERATIONS)
#       <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> print(f"Number of calls: {fitness.calls}")
#
# c:\Users\giobo\Documents\Magistrale_2anno\Computational_Intelligence\Computational_Intelligence\Lab9\lab9.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     parent1 = tournament_selection(population, tournament_size)
#       <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>     parent2 = tournament_selection(population, tournament_size)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a>     offspring.append(uniform_sub_chuncks_crossover(parent1, parent2))
#      <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> for index, ind in enumerate(offspring):
#      <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a>     if random() < mutation_rate:
#
# c:\Users\giobo\Documents\Magistrale_2anno\Computational_Intelligence\Computational_Intelligence\Lab9\lab9.ipynb Cell 11 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=41'>42</a>     else:
#      <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=42'>43</a>         genome += parent2.sub_chunks[i]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=43'>44</a> return Individual(genome=genome,fit=fitness(genome),k=K)
#
# c:\Users\giobo\Documents\Magistrale_2anno\Computational_Intelligence\Computational_Intelligence\Lab9\lab9.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     k = k * 2
#       <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> self.sub_chunks = [self.genome[i:i+k] for i in range(0, len(self.genome), k)]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> self.fitness_chunk = [self.chunk_fitness_alredy_computed(i) for i in range(len(self.sub_chunks))]
#
# c:\Users\giobo\Documents\Magistrale_2anno\Computational_Intelligence\Computational_Intelligence\Lab9\lab9.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     k = k * 2
#       <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> self.sub_chunks = [self.genome[i:i+k] for i in range(0, len(self.genome), k)]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/giobo/Documents/Magistrale_2anno/Computational_Intelligence/Computational_Intelligence/Lab9/lab9.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> self.fitness_chunk = [self.chunk_fitness_alredy_computed(i) for i in range(len(self.sub_chunks))]
#
# KeyboardInterrupt:
